# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np

# !wget -c https://files.grouplens.org/datasets/tag-genome/tag-genome.zip -O tag-genome.zip

# %%
# !unzip tag-genome.zip
# Out:
# Archive:  tag-genome.zip
# replace tag-genome/README.htm? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
tags_df = pd.read_csv('tag-genome/tags.dat', delimiter='\t', header=None, names=["tag_id", "tag", "tag_popularity"])
tags_df.head()
# Out:
#    tag_id           tag  tag_popularity
# 0       0           007              61
# 1       1  007 (series)              24
# 2       2  18th century              37
# 3       3         1920s              42
# 4       4         1930s              55

# %%
movies_df = pd.read_csv('tag-genome/movies.dat', delimiter='\t', header=None, names=["movie_id", "title", "movie_popularity"])
movies_df.head()
# Out:
#    movie_id                               title  movie_popularity
# 0         1                    Toy Story (1995)             53059
# 1         2                      Jumanji (1995)             22466
# 2         3             Grumpier Old Men (1995)             15111
# 3         4            Waiting to Exhale (1995)              2898
# 4         5  Father of the Bride Part II (1995)             14323

# %%
tag_relevance_df = pd.read_csv('tag-genome/tag_relevance.dat', delimiter='\t', header=None, names=["movie_id", "tag_id", "relevance"])
tag_relevance_df.head()
# Out:
#    movie_id  tag_id  relevance
# 0         1       0      0.032
# 1         1       1      0.035
# 2         1       2      0.070
# 3         1       3      0.114
# 4         1       4      0.105

# %%
# !unzip /content/drive/MyDrive/inspiritdata/archive.zip
# Out:
# Archive:  /content/drive/MyDrive/inspiritdata/archive.zip
# replace 2018-personality-data.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
personality_df = pd.read_csv('2018-personality-data.csv')
personality_df.head()
# print(personality_df)
# Out:
#                              userid   openness   agreeableness  \
# 0  8e7cebf9a234c064b75016249f2ac65e        5.0             2.0
# 1  77c7d756a093150d4377720abeaeef76        7.0             4.0
# 2  b7e8a92987a530cc368719a0e60e26a3        4.0             3.0
# 3  92561f21446e017dd6b68b94b23ad5b7        5.5             5.5
# 4  030001ac2145a938b07e686a35a2d638        5.5             5.5
#
#     emotional_stability   conscientiousness   extraversion  assigned metric  \
# 0                   3.0                 2.5            6.5      serendipity
# 1                   6.0                 5.5            4.0              all
# 2                   4.5                 2.0            2.5      serendipity
# 3                   4.0                 4.5            4.0       popularity
# 4                   3.5                 4.5            2.5       popularity
#
#    assigned condition   movie_1   predicted_rating_1  ...   movie_9  \
# ...

# %%
np.shape(personality_df)
# Out:
# (1834, 34)

# %%
np.sum(personality_df.isnull())
# Out:
# userid                  0
#  openness               0
#  agreeableness          0
#  emotional_stability    0
#  conscientiousness      0
#  extraversion           0
#  assigned metric        0
#  assigned condition     0
#  movie_1                0
#  predicted_rating_1     0
#  movie_2                0
#  predicted_rating_2     0
#  movie_3                0
#  predicted_rating_3     0
#  movie_4                0
#  predicted_rating_4     0
#  movie_5                0
#  predicted_rating_5     0
#  movie_6                0
#  predicted_rating_6     0
#  movie_7                0
#  predicted_rating_7     0
#  movie_8                0
#  predicted_rating_8     0
#  movie_9                0
#  predicted_rating_9     0
#  movie_10               0
#  predicted_rating_10    0
#  movie_11               0
#  predicted_rating_11    0
#  movie_12               0
#  predicted_rating_12    0
#  is_personalized        0
#  enjoy_watching         0
# dtype: int64

# %%
print(personality_df.columns)
# Out:
# Index(['userid', ' openness', ' agreeableness', ' emotional_stability',
#        ' conscientiousness', ' extraversion', ' assigned metric',
#        ' assigned condition', ' movie_1', ' predicted_rating_1', ' movie_2',
#        ' predicted_rating_2', ' movie_3', ' predicted_rating_3', ' movie_4',
#        ' predicted_rating_4', ' movie_5', ' predicted_rating_5', ' movie_6',
#        ' predicted_rating_6', ' movie_7', ' predicted_rating_7', ' movie_8',
#        ' predicted_rating_8', ' movie_9', ' predicted_rating_9', ' movie_10',
#        ' predicted_rating_10', ' movie_11', ' predicted_rating_11',
#        ' movie_12', ' predicted_rating_12', ' is_personalized',
#        ' enjoy_watching '],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

le.fit(personality_df[' assigned metric'])
assigned_metric_numerical_features = le.transform(personality_df[' assigned metric'])
personality_df[' assigned metric num'] = assigned_metric_numerical_features

le.fit(personality_df[' assigned condition'])
assigned_condition_numerical_features = le.transform(personality_df[' assigned condition'])
personality_df[' assigned condition num'] = assigned_condition_numerical_features

personality_df.head()
# Out:
#                              userid   openness   agreeableness  \
# 0  8e7cebf9a234c064b75016249f2ac65e        5.0             2.0
# 1  77c7d756a093150d4377720abeaeef76        7.0             4.0
# 2  b7e8a92987a530cc368719a0e60e26a3        4.0             3.0
# 3  92561f21446e017dd6b68b94b23ad5b7        5.5             5.5
# 4  030001ac2145a938b07e686a35a2d638        5.5             5.5
#
#     emotional_stability   conscientiousness   extraversion  assigned metric  \
# 0                   3.0                 2.5            6.5      serendipity
# 1                   6.0                 5.5            4.0              all
# 2                   4.5                 2.0            2.5      serendipity
# 3                   4.0                 4.5            4.0       popularity
# 4                   3.5                 4.5            2.5       popularity
#
#    assigned condition   movie_1   predicted_rating_1  ...   movie_10  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

le.fit(movies_df['title'])
assigned_condition_numerical_features = le.transform(movies_df['title'])
movies_df['title num'] = assigned_condition_numerical_features

movies_df.head()
# Out:
#    movie_id                               title  movie_popularity  title num
# 0         1                    Toy Story (1995)             53059       8864
# 1         2                      Jumanji (1995)             22466       4680
# 2         3             Grumpier Old Men (1995)             15111       3679
# 3         4            Waiting to Exhale (1995)              2898       9245
# 4         5  Father of the Bride Part II (1995)             14323       2985

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
principal_components = pca.fit_transform(personality_df[[" openness", " agreeableness", " emotional_stability", " conscientiousness", " extraversion", " assigned metric num", " assigned condition num", " is_personalized", " enjoy_watching "]])
principal_df = pd.DataFrame(data = principal_components, columns = ['PC1', 'PC2'])

# %%
import numpy as np
from sklearn.model_selection import train_test_split

train_test_split(personality_df, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)
# Out:
# [                                userid   openness   agreeableness  \
#  1109  20afff354ba5330c4073760dee95e597        6.0             2.0
#  957   8e6ac4f844aceec0f72a5f806d596ef4        5.0             4.0
#  121   4d3868d25a632ec1f26b9bd2d9bc5678        6.5             3.5
#  505   cd08114b641efadee87fd7480dc3285e        4.5             3.0
#  1718  01e4e18e2e21b84ee1c5813fd5d3797f        6.5             4.5
#  ...                                ...        ...             ...
#  534   8f56656a9943cc5310f155e6ac7eee6f        7.0             2.5
#  238   327856e80e5b3d161fe06de77dae0a75        5.0             4.5
#  535   7ff282055122bf318a5e4b75e2b914c6        4.5             6.5
#  509   645f180b11c123a84c5de6759b7129ae        4.0             5.0
#  1570  b05a0c35fb6e8b36ddb92f3164f23245        7.0             5.0
#
#         emotional_stability   conscientiousness   extraversion  \
#  1109                   4.0                 5.0            4.5
# ...

# %%
ratings_df = pd.read_csv('2018_ratings.csv', names=["userid", "movie_id", "rating", "tstamp"])
ratings_df.head()
# Out:
# <ipython-input-15-4f7d52753353>:1: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   ratings_df = pd.read_csv('2018_ratings.csv', names=["userid", "movie_id", "rating", "tstamp"])
#                              userid   movie_id   rating                 tstamp
# 0                             useri   movie_id   rating                tstamp
# 1  8e7cebf9a234c064b75016249f2ac65e          1        5   2001-09-10 17:19:56
# 2  8e7cebf9a234c064b75016249f2ac65e          2        4   2001-09-28 11:34:55
# 3  8e7cebf9a234c064b75016249f2ac65e          3        4   2001-09-28 11:42:50
# 4  8e7cebf9a234c064b75016249f2ac65e          5        5   2001-09-28 11:27:30

# %% [markdown]
# 1) Combine personality_df and ratings_df based on user_id --> new table
# 2) Combine new table with movies_df based on movie_id --> final table
# 3) Final table y = final_table["title"]

# %%
import pandas as pd
personality_and_ratings_df = pd.merge(personality_df, ratings_df)
personality_and_ratings_df.head()
# Out:
#                              userid   openness   agreeableness  \
# 0  8e7cebf9a234c064b75016249f2ac65e        5.0             2.0
# 1  8e7cebf9a234c064b75016249f2ac65e        5.0             2.0
# 2  8e7cebf9a234c064b75016249f2ac65e        5.0             2.0
# 3  8e7cebf9a234c064b75016249f2ac65e        5.0             2.0
# 4  8e7cebf9a234c064b75016249f2ac65e        5.0             2.0
#
#     emotional_stability   conscientiousness   extraversion  assigned metric  \
# 0                   3.0                 2.5            6.5      serendipity
# 1                   3.0                 2.5            6.5      serendipity
# 2                   3.0                 2.5            6.5      serendipity
# 3                   3.0                 2.5            6.5      serendipity
# 4                   3.0                 2.5            6.5      serendipity
#
#    assigned condition   movie_1   predicted_rating_1  ...  \
# 0                high     77658             4.410466  ...
# ...

# %%
final_df = pd.merge(personality_and_ratings_df, movies_df)
final_df.head()
# Out:
#                              userid   openness   agreeableness  \
# 0  4638502dc978788ec9d44e64e43a6757        6.0             4.5
# 1  4638502dc978788ec9d44e64e43a6757        6.0             4.5
# 2  4638502dc978788ec9d44e64e43a6757        6.0             4.5
# 3  4638502dc978788ec9d44e64e43a6757        6.0             4.5
# 4  4638502dc978788ec9d44e64e43a6757        6.0             4.5
#
#     emotional_stability   conscientiousness   extraversion  assigned metric  \
# 0                   4.5                 4.5            4.5              all
# 1                   4.5                 4.5            4.5              all
# 2                   4.5                 4.5            4.5              all
# 3                   4.5                 4.5            4.5              all
# 4                   4.5                 4.5            4.5              all
#
#    assigned condition   movie_1   predicted_rating_1  ...   is_personalized  \
# ...

# %%
final_df = final_df.drop(columns=['title', 'title num', 'userid', ' assigned metric', ' assigned condition', 'tstamp'])

for i in range(1,13):
  drop = " movie_" + str(i)
  drop_2 = " predicted_rating_" + str(i)
  final_df = final_df.drop(columns = [drop, drop_2])

# %%
# final_df = data to train/test with

import numpy as np
array = np.random.choice(len(final_df)-1, int(len(final_df)*.95), replace=False)
labels_to_drop = final_df.index[array]
df_dropped = final_df.drop(labels_to_drop)

# %%
y = df_dropped['title num']
y.head()

df_dropped.head()
# Out:
#       openness   agreeableness   emotional_stability   conscientiousness  \
# 13         5.5             7.0                   5.5                 6.0
# 27         5.0             3.5                   6.0                 5.5
# 80         5.0             3.5                   5.5                 3.5
# 82         7.0             3.0                   6.0                 3.5
# 129        6.0             3.0                   7.0                 7.0
#
#       extraversion   is_personalized   enjoy_watching    assigned metric num  \
# 13             4.0                 4                 4                     1
# 27             2.0                 3                 4                     2
# 80             3.0                 2                 4                     2
# 82             2.5                 3                 4                     0
# 129            3.5                 3                 4                     0
#
#       assigned condition num movie_id rating  movie_popularity
# ...

# %%
np.shape(df_dropped)
# Out:
# (38270, 12)

# %%
np.shape(final_df)
# Out:
# (765397, 12)

# %%
X.head()
# Out:
#     openness   agreeableness   emotional_stability   conscientiousness  \
# 0        6.0             4.5                   4.5                 4.5
# 1        6.0             4.5                   4.5                 4.5
# 2        6.0             4.5                   4.5                 4.5
# 3        6.0             4.5                   4.5                 4.5
# 4        6.0             4.5                   4.5                 4.5
#
#     extraversion   is_personalized   enjoy_watching    assigned metric num  \
# 0            4.5                 3                 2                     0
# 1            4.5                 3                 2                     0
# 2            4.5                 3                 2                     0
# 3            4.5                 3                 2                     0
# 4            4.5                 3                 2                     0
#
#     assigned condition num movie_id rating  movie_popularity
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_dropped, y, test_size=0.2)

# %%
print("X_train dimension: ", X_train.shape)
print("X_test dimension: ", X_test.shape)
print("y_train dimension: ", y_train.shape)
print("y_test dimension: ", y_test.shape)
# Out:
# X_train dimension:  (612317, 12)
# X_test dimension:  (153080, 12)
# y_train dimension:  (612317,)
# y_test dimension:  (153080,)

# %%
from sklearn.linear_model import LogisticRegression

logistic_model = LogisticRegression(multi_class="ovr",  max_iter=2, solver="saga")

# %%
logistic_model.fit(X_train, y_train)

# %%
predictions = logistic_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

score = accuracy_score(y_test, predictions)
print('Logistic Regression Model Accuracy: {:.2%}'.format(score))

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

mae_values = []
for k in range(2, 4):
  random_forest_model = RandomForestRegressor(max_depth=k, random_state=0)
  random_forest_model.fit(X_train, y_train)
  predictions = random_forest_model.predict(X_test)
  mae_values.append(mean_absolute_error(y_test, predictions))

plt.figure(figsize=(10,6))
plt.plot(range(1, 16), mae_values)
